# %% [markdown]
# # 3.튜플
# 여러개의 값을 담고 있는 변수.

# %% [markdown]
# ## 3-1.튜플 형식
# <pre>
# * 튜플이름 = (값1, 값2, 값3, ...)
#   튜플이름 = () <- 빈 튜플
#   튜플이름 = (값1,) <- 값 하나인 튜플
#
# * 튜플 이름으로 안되는 것들 :
#   - if, def, class, while, for, else 등의 예약어.
#   - 숫자로 시작하는 것
#   ex) 1a, 3name, ...
#
# * 튜플 특징
#   1.순서가 존재
#   2.값을 인덱스로 불러옴
#   3.값 수정 불가

# %% [markdown]
# ## 3-2. 튜플 다루기
# 리스트와 유사

# %%
tuple1 = (1,2,3)
tuple2 = (2)

# %%
print(tuple1)
# Out:
# (1, 2, 3)

# %% [markdown]
# ### 튜플 인덱스
# <pre>
# *사용법:
# 튜플이름[인덱스]

# %%
a = (3, 5, 'z', 'x')

# %%
print(a[0])
print(a[1])
print(a[2])
print(a[-1])
# Out:
# 3
# 5
# z
# x

# %% [markdown]
# ### 튜플 슬라이스
# <pre>
# *사용법:
# 튜플이름[시작 인덱스:원하는 인덱스+1]

# %%
a = (3, 5, 'z', 'x')

# %%
# 1,2번 인덱스만 뽑아내고 싶다면
print(a[1:3])
# Out:
# (5, 'z')

# %% [markdown]
# ### 튜플 더하기
# '+'

# %%
q = (1,2,3,4)
w = ('z', 'x')

# %%
z = q + w
print(z)
# Out:
# (1, 2, 3, 4, 'z', 'x')

# %% [markdown]
# ### 튜플 곱하기
# '*'

# %%
w = ('z', 'x')

# %%
print(w*3)
# Out:
# ('z', 'x', 'z', 'x', 'z', 'x')

# %% [markdown]
# ### 튜플 길이 구하기
# <pre>
# * 사용법:
# len(튜플)

# %%
q = (1,2,3,4)

# %%
print(len(q))
# Out:
# 4

# %% [markdown]
# ### 튜플<->리스트 변환하기
# <pre>
# 튜플 -> 리스트 :
# list(튜플)
#
# 리스트 ->튜플 :
# tuple(리스트)

# %%
tuple1 = (1,2,3,4)

# %%
# 튜플 -> 리스트
list1 = list(tuple1)
print(list1)
# Out:
# [1, 2, 3, 4]

# %%
list2 = [1,2,3,4]

# %%
# 리스트 -> 튜플
tuple2 = tuple(list2)
print(tuple2)
# Out:
# (1, 2, 3, 4)
