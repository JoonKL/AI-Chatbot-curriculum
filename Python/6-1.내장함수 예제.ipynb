# %% [markdown]
# ### 01. ;을 이용하여 코드를 한 줄로 만드세요.

# %%
print('오늘 제 생일이에요.')
print('축하해 주세요.')

# %% [markdown]
# ### 02. print()함수에 ,end를 넣어서 예시와 같이 출력되게 하세요.
# <pre>
# 예시:
# 오늘은 제 생일이에요. 축하해 주세요.

# %%
print('오늘은 제 생일이에요.')
print('축하해 주세요.')

# %% [markdown]
# ### 03. ,를 이용해서 예시와 같이 출력되게 하세요.
# <pre>
# 예시:
# 즉, 우리는 할 수 있습니다.

# %%
print('즉')
print('우리는 할 수 있습니다.')

# %% [markdown]
# ### 04. 다음의 주어진 변수를 가지고 예시처럼 출력되게 만드세요.
# ### 힌트 : print()를 두번 쓰세요.
# <pre>
# 예시:
# 호의가 계속되면, 둘린 줄 알아요.

# %%
a='호의'
b='둘리'

# %% [markdown]
# ### 05.콤마 , 를 이용해서 아래 예시처럼 출력하세요.
# <pre>
# 예시:
# I love my life

# %% [markdown]
# ### 06. 아래 변수들의 들의 타입을 확인하세요.

# %%
a=3

# %%
b='철수'

# %%
c='7'

# %%
d=9.0

# %%
e=['a','b','c']

# %%
q=('명예', '돈', '사람')

# %%
w={'z':e, 'x':q}

# %% [markdown]
# ### Q7. 다음 변수들의 길이를 구하세요.

# %%
a='나 슬퍼도 살아야 하네 나 슬퍼도 살아야 하네 이예'

# %%
b=[1,2,3,4,1,2,3,1,2,3,1,2,3,1,2,3,1,2]

# %%
c=('q', 'w', 'e', 1, 'Jim')

# %% [markdown]
# ### Q8. 주어진 변수 a의 값을 정수로 갖는 b 변수를 만드세요.
# ### b의 타입까지 출력해보세요.

# %%
a='01022223333'

# %% [markdown]
# ### Q9. 주어진 변수 a의 값을 정수로 갖는 b 변수를 만드세요.
# ### b의 타입까지 출력해보세요.

# %%
a=3.141592

# %% [markdown]
# ### Q10. 다음 변수 a를 문자열로 바꾸어 b에 저장하세요.

# %%
a=132

# %% [markdown]
# ### Q11.a라는 변수에 사용자 입력으로 2를 넣어보세요.

# %% [markdown]
# ### Q12. b라는 변수에 사용자 입력으로 철수를 넣으세요.

# %% [markdown]
# ### Q13. c라는 변수를 사용자 입력으로 받되 '나이를 입력하세요.>'를 넣어 받으세요.
# ### 나이를 넣어 c에 저장하세요.

# %% [markdown]
# ### Q14. 13번 문제의 c의 타입을 확인하세요.

# %% [markdown]
# ### Q15. d라는 변수를 사용자 입력으로 받되 '숫자를 입력하세요.>'를 넣어 받으세요.
# ### 그리고 그 값이 정수가 되게 받아서 저장하세요.

# %% [markdown]
# ### Q16. 다음 변수 a를 리스트로 만들어 b에 저장하세요.

# %%
a= '나 보기가 역겨워 가실 때에는 말 없이 고이 보내 드리오리다'

# %%
a= [1,3,5,7,9]

# %% [markdown]
# ### Q17. range()함수를 이용하여 라는 리스트를 만드세요.
# ### 값은 1부터 10까지 들어가게 만드세요.

# %% [markdown]
# ### Q18. range()함수를 이용하여 2,4,6,8,10을 갖는 b라는 리스트를 만드세요.
