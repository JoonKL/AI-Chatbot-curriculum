# %% [markdown]
# ### Q001. number 라는 이름의 변수에 1을 넣으세요.

# %%
number=1

# %% [markdown]
# ### Q002. 변수 a와 변수 b가 주어질 때, 그 합을 c에 넣으세요.
# ### 출력도 해보세요.

# %%
a = 7
b = 4
c=a+b
print(c)
# Out:
# 11

# %% [markdown]
# ### Q003. 3번 문제의 a를 b로 나눗셈 하여 d에 넣으세요.
# ### 출력까지 해보세요.

# %%
d=a/b
print(d)
# Out:
# 1.75

# %% [markdown]
# ### Q004. 3번의 a를 b로 나눗셈의 몫 연산한 것을 출력하세요.

# %%
d=a//b
print(d)
# Out:
# 1

# %% [markdown]
# ### Q005. 3번의 a를 b로 나눗셈의 나머지 연산 한 것을 출력하세요.

# %%
d=a%b
print(d)
# Out:
# 3

# %% [markdown]
# ### Q006. 3번의 a를 b제곱 한 결과를 출력하세요.

# %%
d=a**b
print(d)
# Out:
# 2401

# %% [markdown]
# ### Q007. 자신의 이름을 출력하세요.

# %%
a='이준기'
print(a)
# Out:
# 이준기

# %% [markdown]
# ### Q008. 자신의 이름을 a라는 변수에 넣으세요.

# %%
a='이준기'

# %% [markdown]
# ### Q009. 아래 문장을 문자열 처리해서 b 라는 변수에 넣으세요.

# %%
b="""화려한 도시를 그리며 찾아왔네.
그곳은 춥고도 험한 곳."""
print(b)
# Out:
# 화려한 도시를 그리며 찾아왔네.
# 그곳은 춥고도 험한 곳.

# %% [markdown]
# ### Q010. 아래 예시처럼 출력될 수 있도록 문자열로 만들어 보세요.
# <pre>
# 내 동생은 말했다. "걸그룹은 역시 AOA야."

# %%
q='내 동생은 말했다. "걸그룹은 역시 AOA야"'
print(q)
# Out:
# 내 동생은 말했다. "걸그룹은 역시 AOA야"

# %% [markdown]
# ### Q011. 아래 문장을 전체 주석처리 해보세요.

# %%
'''내 모습이 보이지 않아
앞길도 보이지 않아
나는 상처 많은 번데기'''

# %% [markdown]
# ### Q012. 아래 변수에 * 2를 해서 출력하세요.

# %%
a = '대한민국'
print(a*2)
# Out:
# 대한민국대한민국

# %% [markdown]
# ### Q013. 아래 예시와 같이 출력하세요. 횟수는 30으로 합니다.
# <pre>
# 예시
# ----------------------

# %%
a='-'
print('예시')
print(a*30)
# Out:
# 예시
# ------------------------------

# %% [markdown]
# ### Q014. 아래 변수의 길이를 구하세요.

# %%
a = '오늘은 든든한 곰국을 먹어야 겠다.'
len(a)
# Out:
# 19

# %% [markdown]
# ### Q015. 아래 변수에서 '장'만을 출력하세요.

# %%
a = '이에 표창장을 수여합니다.'
print(a[5])
# Out:
# 장

# %% [markdown]
# ### Q016. 아래 변수에서 '사랑은' 을 출력하세요.

# %%
b = '사랑은 가슴이 시킨다.'
print(b[:3])
# Out:
# 사랑은

# %% [markdown]
# ### Q017. 아래 변수를 이용하여 예시와 같은 문자열을 출력하세요.
# <pre>
# 예시:
# 사람이 꽃보다 아름다워

# %%
a = '사람'
print(a+'이 꽃보다 아름다워')
# Out:
# 사람이 꽃보다 아름다워

# %% [markdown]
# ### Q018. 아래 변수들을 넣어서 예시와 같은 문자열을 출력하세요.
# <pre>
# 예시:
# 올해는 2019년 이니까 내년은 2020년이네.

# %%
a = 2019
b = 2020
print('올해는 {}년 이니까 내년은 {}년 이네.'.format(a,b))
# Out:
# 올해는 2019년 이니까 내년은 2020년 이네.

# %% [markdown]
# ### Q019. 아래 변수에서 '장'의 갯수를 출력하세요.

# %%
a = '간장공장공장장은 강공장장이다.'
a.count('장')
# Out:
# 6

# %% [markdown]
# ### Q020. 아래 변수에서 '병수'를 '민수'로 바꾸어 출력하세요.

# %%
a = '병수는 우리반 반장이야.'
b=a.replace('병수','민수')
print(b)
# Out:
# 민수는 우리반 반장이야.

# %% [markdown]
# ### Q021. 아래 변수를 공백 단위로 나누어 출력해 보세요.

# %%
a = 'I am your father'
a.split()
# Out:
# ['I', 'am', 'your', 'father']
